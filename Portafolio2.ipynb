# %% [markdown]
# **Pregunta 1 - Extracción de datos de acciones de Tesla utilizando yfinance - 2 Puntos**

# %%
import yfinance as yf

# %%
tesla_df = yf.Ticker("TSLA").history(period="5y")
print(tesla_df.head())
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-12-09 00:00:00-05:00  22.439333  22.963333  22.338667  22.635332
# 2019-12-10 00:00:00-05:00  22.664000  23.382000  22.620667  23.256001
# 2019-12-11 00:00:00-05:00  23.458668  23.812668  23.406000  23.513332
# 2019-12-12 00:00:00-05:00  23.661333  24.182667  23.548668  23.978666
# 2019-12-13 00:00:00-05:00  24.070000  24.347334  23.642668  23.892668
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-12-09 00:00:00-05:00  135346500        0.0           0.0
# 2019-12-10 00:00:00-05:00  132424500        0.0           0.0
# 2019-12-11 00:00:00-05:00  103467000        0.0           0.0
# 2019-12-12 00:00:00-05:00  116458500        0.0           0.0
# 2019-12-13 00:00:00-05:00   98563500        0.0           0.0

# %% [markdown]
# **Pregunta 2 - Extracción de datos de ingresos de Tesla utilizando Webscraping - 1 Puntos**

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
table = soup.find_all("table")[1]  
rows = table.find_all("tr")
tesla_revenue = []
for row in rows[1:]:
    cols = row.find_all("td")
    tesla_revenue.append([col.text.strip() for col in cols])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[54], line 4
#       2 response = requests.get(url)
#       3 soup = BeautifulSoup(response.text, "html.parser")
# ----> 4 table = soup.find_all("table")[1]
#       5 rows = table.find_all("tr")
#       6 tesla_revenue = []
#
# IndexError: list index out of range

# %% [markdown]
# **Pregunta 3 - Extracción de datos de acciones de GameStop utilizando yfinance - 2 Puntos**

# %%
gamestop_df = yf.Ticker("GME").history(period="5y")
print(gamestop_df.head())
# Out:
#                              Open    High     Low   Close    Volume  \
# Date
# 2019-12-09 00:00:00-05:00  1.6625  1.7300  1.5475  1.5825  25002400
# 2019-12-10 00:00:00-05:00  1.5725  1.6350  1.5300  1.6275  38379600
# 2019-12-11 00:00:00-05:00  1.3125  1.4525  1.2950  1.3825  78071200
# 2019-12-12 00:00:00-05:00  1.3650  1.4275  1.3525  1.3950  25549200
# 2019-12-13 00:00:00-05:00  1.3675  1.4050  1.3100  1.3625  21756000
#
#                            Dividends  Stock Splits
# Date
# 2019-12-09 00:00:00-05:00        0.0           0.0
# 2019-12-10 00:00:00-05:00        0.0           0.0
# 2019-12-11 00:00:00-05:00        0.0           0.0
# 2019-12-12 00:00:00-05:00        0.0           0.0
# 2019-12-13 00:00:00-05:00        0.0           0.0

# %% [markdown]
# **Pregunta 4 - Extracción de datos de ingresos de GameStop utilizando Webscraping - 1 Puntos**

# %%
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

table = soup.find_all("table")[1]  
rows = table.find_all("tr")
gamestop_revenue = []
for row in rows[1:]:
    cols = row.find_all("td")
    gamestop_revenue.append([col.text.strip() for col in cols])

print(gamestop_revenue[:5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 7
#       4 soup = BeautifulSoup(response.text, "html.parser")
#       6 # Extraer tabla de ingresos
# ----> 7 table = soup.find_all("table")[1]  # Tabla específica
#       8 rows = table.find_all("tr")
#       9 gamestop_revenue = []
#
# IndexError: list index out of range

# %% [markdown]
# **Pregunta 5 - Tablero de acciones e ingresos de Tesla - 2 Puntos**

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

tesla_df['Close'].plot(title="Tesla Stock Prices", label="Stock Price", legend=True)
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.show()

# %% [markdown]
# Pregunta 6 - Cuadro de mando de acciones e ingresos de GameStop

# %%
gamestop_data['Close'].plot(title="GameStop Stock Prices", label="Stock Price", legend=True)
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.show()

# %% [markdown]
# Pregunta 7 - Compartir su cuaderno de tareas - 2 Puntos
